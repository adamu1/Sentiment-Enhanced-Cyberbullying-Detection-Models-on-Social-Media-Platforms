# %% [markdown]
# Sentiment Analysis for Cyberbullying Detection on Social Media Platforms using DeepSeek-coder-1.3b-base

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from datasets import Dataset
import re
import string
import unicodedata

# %%
# Load dataset
df = pd.read_csv('../Datasets/preprocessed_Amazon_Updated.csv', encoding='ISO-8859-1')  
df = df[['text', 'sentiment']].dropna()

# %%
# Optional: Integrate sentiment score (you can use TextBlob or Vader here)
#from textblob import TextBlob

#def get_sentiment(text):
    #return TextBlob(text).sentiment.polarity

#df['sentiment'] = df['selected_text'].apply(get_sentiment)
#df['text'] = df['sentiment'].astype(str) + ' ' + df['selected_text']  # prepend sentiment to input

# %%
# Encode labels
labels = df['sentiment'].unique().tolist()
df['label'] = df['sentiment'].apply(lambda x: labels.index(x))

# %%
df
# Out:
#                                                     text sentiment  label
# 0      my lovely pat has one of the great voices of h...  positive      0
# 1      despite the fact that i have only played a sma...  positive      0
# 2      i bought this charger in jul and it worked ok ...  negative      1
# 3      check out maha energys website their powerex m...  positive      0
# 4      reviewed quite a bit of the combo players and ...  positive      0
# ...                                                  ...       ...    ...
# 41404  tea tree shampoo is my favorite i usually get ...  positive      0
# 41405  admittedly i am not a country music fan howeve...  positive      0
# 41406  i try to listen to something new everyday and ...  positive      0
# 41407  i bought this to go inside of the enclosed woo...  negative      1
# 41408  terribly disappointing that she has left the a...  negative      1
#
# [41409 rows x 3 columns]

# %%
# Train/test split
train_df, test_df = train_test_split(df[['text', 'label']], test_size=0.2, random_state=42)
train_dataset = Dataset.from_pandas(train_df)
test_dataset = Dataset.from_pandas(test_df)

# %%
from transformers import AutoTokenizer

model_name = "deepseek-ai/deepseek-coder-1.3b-base"
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)

#from transformers import AutoModelForSequenceClassification, AutoTokenizer

#model = AutoModelForSequenceClassification.from_pretrained("./fine-tuned-deepseek-coder-1.3b-based-text-classification")
#tokenizer = AutoTokenizer.from_pretrained("./fine-tuned-deepseek-coder-1.3b-based-text-classification")

# %%
# Tokenize
def tokenize(batch):
    return tokenizer(batch['text'], truncation=True, padding='max_length', max_length=128)

train_dataset = train_dataset.map(tokenize, batched=True)
test_dataset = test_dataset.map(tokenize, batched=True)

train_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])
test_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])
# Out:
# Map:   0%|          | 0/33127 [00:00<?, ? examples/s]
# Map:   0%|          | 0/8282 [00:00<?, ? examples/s]

# %% [markdown]
# 🧠 Customize DeepSeek Model for Classification

# %%
import torch
from torch import nn
from transformers import AutoModel, PreTrainedModel, PretrainedConfig

class DeepSeekForClassification(PreTrainedModel):
    def __init__(self, config, num_labels):
        super().__init__(config)
        self.num_labels = num_labels
        self.model = AutoModel.from_pretrained(model_name, trust_remote_code=True)
        self.dropout = nn.Dropout(0.1)
        self.classifier = nn.Linear(config.hidden_size, num_labels)

    def forward(self, input_ids, attention_mask=None, labels=None):
        outputs = self.model(input_ids=input_ids, attention_mask=attention_mask)
        hidden_state = outputs.last_hidden_state  # (batch_size, seq_len, hidden_dim)
        pooled_output = hidden_state[:, 0]  # take <s> token (CLS token)
        pooled_output = self.dropout(pooled_output)
        logits = self.classifier(pooled_output)

        loss = None
        if labels is not None:
            loss_fn = nn.CrossEntropyLoss()
            loss = loss_fn(logits, labels)

        return {"loss": loss, "logits": logits}

# %% [markdown]
# ⚙️ Training Setup

# %%
from transformers import TrainingArguments, Trainer, EvalPrediction
import numpy as np
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

# %%
from transformers import PretrainedConfig

# Custom configuration class
class CustomConfig(PretrainedConfig):
    def __init__(self, num_labels=2, hidden_size=2048, **kwargs):
        super().__init__(**kwargs)
        self.hidden_size = hidden_size  # default for DeepSeek 1.3B
        self.num_labels = num_labels

num_labels = 2  # for example, if you have 2 classes
config = CustomConfig(num_labels=num_labels)
model = DeepSeekForClassification(config=config, num_labels=num_labels)

# %%
# Metrics
def compute_metrics(eval_pred: EvalPrediction):
    logits, labels_ = eval_pred
    predictions = np.argmax(logits, axis=-1)
    precision, recall, f1, _ = precision_recall_fscore_support(labels_, predictions, average='weighted')
    acc = accuracy_score(labels_, predictions)
    return {"accuracy": acc, "f1": f1, "precision": precision, "recall": recall}

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
    output_dir="./deepseek_cyberbullying",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    logging_strategy="steps",
    logging_steps=10,
    learning_rate=2e-5,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    num_train_epochs=1,
    weight_decay=0.01,
    # fp16=True,  # ❌ Comment out this line, as it's only for GPU/TPU (mixed precision)
    report_to="none",
    load_best_model_at_end=True,
    metric_for_best_model="f1",
)
# Out:
# C:\Users\USTB\anaconda3\Lib\site-packages\transformers\training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
from transformers import TrainerCallback

class PrintEpochCallback(TrainerCallback):
    def on_epoch_end(self, args, state, control, **kwargs):
        print(f"Epoch {int(state.epoch)} finished. Current loss: {state.log_history[-1]}")

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics,
    callbacks=[PrintEpochCallback()],
)

# %% [markdown]
# 🚀 Train and Evaluate

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='8282' max='8282' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [8282/8282 21:00:00, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000000</td>
#       <td>nan</td>
#       <td>0.519198</td>
#       <td>0.354880</td>
#       <td>0.269567</td>
#       <td>0.519198</td>
#     </tr>
#   </tbody>
# </table><p>
# Epoch 1 finished. Current loss: {'loss': 0.0, 'grad_norm': nan, 'learning_rate': 4.829751267809708e-09, 'epoch': 0.9997585124366095, 'step': 8280}
# C:\Users\USTB\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# TrainOutput(global_step=8282, training_loss=0.0812245405575297, metrics={'train_runtime': 75611.5698, 'train_samples_per_second': 0.438, 'train_steps_per_second': 0.11, 'total_flos': 3.089506810150349e+16, 'train_loss': 0.0812245405575297, 'epoch': 1.0})

# %% [markdown]
# Save Model

# %%
# Save the fine-tuned model locally
#model_save_path = "./fine-tuned-deepseek-coder-1.3b-based-text-classification-IMDB"

# Save model and tokenizer
#model.save_pretrained(model_save_path)
#tokenizer.save_pretrained(model_save_path)

#print(f"Model and tokenizer saved to {model_save_path}")

# %% [markdown]
# Push to Hugging Face Hub

# %%
# Log in first if needed
#from huggingface_hub import notebook_login
#notebook_login()

# Push model and tokenizer
#trainer.push_to_hub("Fine-tuned DeepSeek Coder - Text Classification")

# %%
# Evaluation
import time
import psutil
from codecarbon import EmissionsTracker

# Start tracking energy consumption
tracker = EmissionsTracker()
tracker.start()

# Measure CPU and RAM usage before evaluation
process = psutil.Process()
cpu_before = psutil.cpu_percent(interval=None)
ram_before = process.memory_info().rss / (1024 * 1024)  # Convert to MB

# Measure inference time
start_time = time.time()

# Evaluation
metrics = trainer.evaluate()

# Measure inference time
end_time = time.time()
inference_time = end_time - start_time

# Measure CPU and RAM usage after evaluation
cpu_after = psutil.cpu_percent(interval=None)
ram_after = process.memory_info().rss / (1024 * 1024)  # Convert to MB

# Calculate differences
cpu_usage = cpu_after - cpu_before
ram_usage = ram_after - ram_before

# Stop energy tracking
emissions = tracker.stop()

# Print results
print(metrics)
print(f"Inference Time: {inference_time:.4f} seconds")
print(f"CPU Usage: {cpu_usage:.2f}%")
print(f"RAM Usage: {ram_usage:.2f} MB")
print(f"Energy Consumption: {emissions:.6f} kWh")
# Out:
# [codecarbon INFO @ 15:52:39] [setup] RAM Tracking...
# [codecarbon INFO @ 15:52:39] [setup] GPU Tracking...
# [codecarbon INFO @ 15:52:39] Tracking Nvidia GPU via pynvml
# [codecarbon INFO @ 15:52:39] [setup] CPU Tracking...
# [codecarbon WARNING @ 15:52:39] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon WARNING @ 15:52:41] We saw that you have a 13th Gen Intel(R) Core(TM) i9-13900 but we don't know it. Please contact us.
# [codecarbon INFO @ 15:52:41] CPU Model on constant consumption mode: 13th Gen Intel(R) Core(TM) i9-13900
# [codecarbon INFO @ 15:52:41] >>> Tracker's metadata:
# [codecarbon INFO @ 15:52:41]   Platform system: Windows-10-10.0.26100-SP0
# [codecarbon INFO @ 15:52:41]   Python version: 3.11.5
# [codecarbon INFO @ 15:52:41]   CodeCarbon version: 2.2.2
# [codecarbon INFO @ 15:52:41]   Available RAM : 31.696 GB
# [codecarbon INFO @ 15:52:41]   CPU count: 32
# [codecarbon INFO @ 15:52:41]   CPU model: 13th Gen Intel(R) Core(TM) i9-13900
# [codecarbon INFO @ 15:52:41]   GPU count: 1
# [codecarbon INFO @ 15:52:41]   GPU model: 1 x NVIDIA GeForce RTX 4090
#     <div>
#
#       <progress value='2071' max='2071' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2071/2071 1:08:24]
#     </div>
# [codecarbon INFO @ 15:52:59] Energy consumed for RAM : 0.000050 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:52:59] Energy consumed for all GPUs : 0.000253 kWh. Total GPU Power : 60.64 W
# [codecarbon INFO @ 15:52:59] Energy consumed for all CPUs : 0.000178 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:52:59] 0.000481 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:53:14] Energy consumed for RAM : 0.000099 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:53:14] Energy consumed for all GPUs : 0.000507 kWh. Total GPU Power : 60.893 W
# [codecarbon INFO @ 15:53:14] Energy consumed for all CPUs : 0.000355 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:53:14] 0.000961 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:53:29] Energy consumed for RAM : 0.000149 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:53:29] Energy consumed for all GPUs : 0.000757 kWh. Total GPU Power : 59.844 W
# [codecarbon INFO @ 15:53:29] Energy consumed for all CPUs : 0.000532 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:53:29] 0.001437 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:53:44] Energy consumed for RAM : 0.000198 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:53:44] Energy consumed for all GPUs : 0.001010 kWh. Total GPU Power : 60.853 W
# [codecarbon INFO @ 15:53:44] Energy consumed for all CPUs : 0.000709 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:53:44] 0.001918 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:53:59] Energy consumed for RAM : 0.000248 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:53:59] Energy consumed for all GPUs : 0.001260 kWh. Total GPU Power : 59.922000000000004 W
# [codecarbon INFO @ 15:53:59] Energy consumed for all CPUs : 0.000887 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:53:59] 0.002395 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:54:14] Energy consumed for RAM : 0.000297 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:54:14] Energy consumed for all GPUs : 0.001512 kWh. Total GPU Power : 60.517 W
# [codecarbon INFO @ 15:54:14] Energy consumed for all CPUs : 0.001064 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:54:14] 0.002874 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:54:29] Energy consumed for RAM : 0.000347 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:54:29] Energy consumed for all GPUs : 0.001765 kWh. Total GPU Power : 60.693 W
# [codecarbon INFO @ 15:54:29] Energy consumed for all CPUs : 0.001241 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:54:29] 0.003353 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:54:44] Energy consumed for RAM : 0.000396 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:54:44] Energy consumed for all GPUs : 0.002019 kWh. Total GPU Power : 60.82 W
# [codecarbon INFO @ 15:54:44] Energy consumed for all CPUs : 0.001418 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:54:44] 0.003833 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:54:59] Energy consumed for RAM : 0.000446 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:54:59] Energy consumed for all GPUs : 0.002269 kWh. Total GPU Power : 60.10800000000001 W
# [codecarbon INFO @ 15:54:59] Energy consumed for all CPUs : 0.001596 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:54:59] 0.004311 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:55:14] Energy consumed for RAM : 0.000495 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:55:14] Energy consumed for all GPUs : 0.002521 kWh. Total GPU Power : 60.32 W
# [codecarbon INFO @ 15:55:14] Energy consumed for all CPUs : 0.001773 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:55:14] 0.004789 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:55:29] Energy consumed for RAM : 0.000545 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:55:29] Energy consumed for all GPUs : 0.002774 kWh. Total GPU Power : 60.751000000000005 W
# [codecarbon INFO @ 15:55:29] Energy consumed for all CPUs : 0.001950 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:55:29] 0.005269 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:55:44] Energy consumed for RAM : 0.000594 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:55:44] Energy consumed for all GPUs : 0.003026 kWh. Total GPU Power : 60.618 W
# [codecarbon INFO @ 15:55:44] Energy consumed for all CPUs : 0.002127 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:55:44] 0.005748 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:55:59] Energy consumed for RAM : 0.000644 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:55:59] Energy consumed for all GPUs : 0.003280 kWh. Total GPU Power : 60.857 W
# [codecarbon INFO @ 15:55:59] Energy consumed for all CPUs : 0.002304 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:55:59] 0.006228 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:56:14] Energy consumed for RAM : 0.000693 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:56:14] Energy consumed for all GPUs : 0.003531 kWh. Total GPU Power : 60.222 W
# [codecarbon INFO @ 15:56:14] Energy consumed for all CPUs : 0.002482 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:56:14] 0.006706 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:56:29] Energy consumed for RAM : 0.000743 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:56:29] Energy consumed for all GPUs : 0.003783 kWh. Total GPU Power : 60.627 W
# [codecarbon INFO @ 15:56:29] Energy consumed for all CPUs : 0.002659 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:56:29] 0.007185 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:56:44] Energy consumed for RAM : 0.000792 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:56:44] Energy consumed for all GPUs : 0.004041 kWh. Total GPU Power : 61.855000000000004 W
# [codecarbon INFO @ 15:56:44] Energy consumed for all CPUs : 0.002836 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:56:44] 0.007670 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:56:59] Energy consumed for RAM : 0.000842 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:56:59] Energy consumed for all GPUs : 0.004292 kWh. Total GPU Power : 60.284 W
# [codecarbon INFO @ 15:56:59] Energy consumed for all CPUs : 0.003013 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:56:59] 0.008148 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:57:14] Energy consumed for RAM : 0.000891 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:57:14] Energy consumed for all GPUs : 0.004543 kWh. Total GPU Power : 60.225 W
# [codecarbon INFO @ 15:57:14] Energy consumed for all CPUs : 0.003191 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:57:14] 0.008626 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:57:29] Energy consumed for RAM : 0.000941 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:57:29] Energy consumed for all GPUs : 0.004793 kWh. Total GPU Power : 59.912 W
# [codecarbon INFO @ 15:57:29] Energy consumed for all CPUs : 0.003368 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:57:29] 0.009102 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:57:44] Energy consumed for RAM : 0.000991 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:57:44] Energy consumed for all GPUs : 0.005042 kWh. Total GPU Power : 59.653 W
# [codecarbon INFO @ 15:57:44] Energy consumed for all CPUs : 0.003545 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:57:44] 0.009578 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:57:59] Energy consumed for RAM : 0.001040 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:57:59] Energy consumed for all GPUs : 0.005293 kWh. Total GPU Power : 60.279 W
# [codecarbon INFO @ 15:57:59] Energy consumed for all CPUs : 0.003723 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:57:59] 0.010056 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:58:14] Energy consumed for RAM : 0.001090 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:58:14] Energy consumed for all GPUs : 0.005543 kWh. Total GPU Power : 59.889 W
# [codecarbon INFO @ 15:58:14] Energy consumed for all CPUs : 0.003900 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:58:14] 0.010533 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:58:29] Energy consumed for RAM : 0.001139 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:58:29] Energy consumed for all GPUs : 0.005795 kWh. Total GPU Power : 60.423 W
# [codecarbon INFO @ 15:58:29] Energy consumed for all CPUs : 0.004077 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:58:29] 0.011011 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:58:44] Energy consumed for RAM : 0.001189 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:58:44] Energy consumed for all GPUs : 0.006045 kWh. Total GPU Power : 60.078 W
# [codecarbon INFO @ 15:58:44] Energy consumed for all CPUs : 0.004255 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:58:44] 0.011489 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:58:59] Energy consumed for RAM : 0.001238 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:58:59] Energy consumed for all GPUs : 0.006296 kWh. Total GPU Power : 60.081 W
# [codecarbon INFO @ 15:58:59] Energy consumed for all CPUs : 0.004432 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:58:59] 0.011966 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:59:14] Energy consumed for RAM : 0.001288 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:59:14] Energy consumed for all GPUs : 0.006547 kWh. Total GPU Power : 60.354 W
# [codecarbon INFO @ 15:59:14] Energy consumed for all CPUs : 0.004609 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:59:14] 0.012444 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:59:29] Energy consumed for RAM : 0.001337 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:59:29] Energy consumed for all GPUs : 0.006799 kWh. Total GPU Power : 60.484 W
# [codecarbon INFO @ 15:59:29] Energy consumed for all CPUs : 0.004786 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:59:29] 0.012922 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:59:44] Energy consumed for RAM : 0.001387 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:59:44] Energy consumed for all GPUs : 0.007053 kWh. Total GPU Power : 60.993 W
# [codecarbon INFO @ 15:59:44] Energy consumed for all CPUs : 0.004963 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:59:44] 0.013403 kWh of electricity used since the beginning.
# [codecarbon INFO @ 15:59:59] Energy consumed for RAM : 0.001436 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 15:59:59] Energy consumed for all GPUs : 0.007307 kWh. Total GPU Power : 60.841 W
# [codecarbon INFO @ 15:59:59] Energy consumed for all CPUs : 0.005141 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 15:59:59] 0.013884 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:00:14] Energy consumed for RAM : 0.001486 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:00:14] Energy consumed for all GPUs : 0.007559 kWh. Total GPU Power : 60.647 W
# [codecarbon INFO @ 16:00:14] Energy consumed for all CPUs : 0.005318 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:00:14] 0.014363 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:00:29] Energy consumed for RAM : 0.001535 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:00:29] Energy consumed for all GPUs : 0.007809 kWh. Total GPU Power : 60.008 W
# [codecarbon INFO @ 16:00:29] Energy consumed for all CPUs : 0.005495 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:00:29] 0.014840 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:00:44] Energy consumed for RAM : 0.001585 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:00:44] Energy consumed for all GPUs : 0.008057 kWh. Total GPU Power : 59.435 W
# [codecarbon INFO @ 16:00:44] Energy consumed for all CPUs : 0.005672 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:00:44] 0.015315 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:00:59] Energy consumed for RAM : 0.001634 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:00:59] Energy consumed for all GPUs : 0.008305 kWh. Total GPU Power : 59.284000000000006 W
# [codecarbon INFO @ 16:00:59] Energy consumed for all CPUs : 0.005850 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:00:59] 0.015788 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:01:14] Energy consumed for RAM : 0.001684 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:01:14] Energy consumed for all GPUs : 0.008553 kWh. Total GPU Power : 59.668 W
# [codecarbon INFO @ 16:01:14] Energy consumed for all CPUs : 0.006027 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:01:14] 0.016264 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:01:29] Energy consumed for RAM : 0.001733 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:01:29] Energy consumed for all GPUs : 0.008802 kWh. Total GPU Power : 59.80500000000001 W
# [codecarbon INFO @ 16:01:29] Energy consumed for all CPUs : 0.006204 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:01:29] 0.016740 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:01:44] Energy consumed for RAM : 0.001783 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:01:44] Energy consumed for all GPUs : 0.009052 kWh. Total GPU Power : 59.874 W
# [codecarbon INFO @ 16:01:44] Energy consumed for all CPUs : 0.006381 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:01:44] 0.017215 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:01:59] Energy consumed for RAM : 0.001832 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:01:59] Energy consumed for all GPUs : 0.009301 kWh. Total GPU Power : 59.899 W
# [codecarbon INFO @ 16:01:59] Energy consumed for all CPUs : 0.006558 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:01:59] 0.017692 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:02:14] Energy consumed for RAM : 0.001882 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:02:14] Energy consumed for all GPUs : 0.009552 kWh. Total GPU Power : 60.1 W
# [codecarbon INFO @ 16:02:14] Energy consumed for all CPUs : 0.006735 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:02:14] 0.018169 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:02:29] Energy consumed for RAM : 0.001931 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:02:29] Energy consumed for all GPUs : 0.009801 kWh. Total GPU Power : 59.882 W
# [codecarbon INFO @ 16:02:29] Energy consumed for all CPUs : 0.006912 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:02:29] 0.018645 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:02:44] Energy consumed for RAM : 0.001981 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:02:44] Energy consumed for all GPUs : 0.010053 kWh. Total GPU Power : 60.369 W
# [codecarbon INFO @ 16:02:44] Energy consumed for all CPUs : 0.007090 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:02:44] 0.019124 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:02:59] Energy consumed for RAM : 0.002031 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:02:59] Energy consumed for all GPUs : 0.010302 kWh. Total GPU Power : 59.694 W
# [codecarbon INFO @ 16:02:59] Energy consumed for all CPUs : 0.007267 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:02:59] 0.019599 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:03:14] Energy consumed for RAM : 0.002080 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:03:14] Energy consumed for all GPUs : 0.010553 kWh. Total GPU Power : 60.308 W
# [codecarbon INFO @ 16:03:14] Energy consumed for all CPUs : 0.007444 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:03:14] 0.020077 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:03:29] Energy consumed for RAM : 0.002130 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:03:29] Energy consumed for all GPUs : 0.010806 kWh. Total GPU Power : 60.71 W
# [codecarbon INFO @ 16:03:29] Energy consumed for all CPUs : 0.007621 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:03:29] 0.020556 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:03:44] Energy consumed for RAM : 0.002179 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:03:44] Energy consumed for all GPUs : 0.011059 kWh. Total GPU Power : 60.863 W
# [codecarbon INFO @ 16:03:44] Energy consumed for all CPUs : 0.007798 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:03:44] 0.021036 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:03:59] Energy consumed for RAM : 0.002229 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:03:59] Energy consumed for all GPUs : 0.011314 kWh. Total GPU Power : 61.121 W
# [codecarbon INFO @ 16:03:59] Energy consumed for all CPUs : 0.007976 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:03:59] 0.021518 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:04:14] Energy consumed for RAM : 0.002278 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:04:14] Energy consumed for all GPUs : 0.011565 kWh. Total GPU Power : 60.321 W
# [codecarbon INFO @ 16:04:14] Energy consumed for all CPUs : 0.008153 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:04:14] 0.021996 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:04:29] Energy consumed for RAM : 0.002328 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:04:29] Energy consumed for all GPUs : 0.011822 kWh. Total GPU Power : 61.59 W
# [codecarbon INFO @ 16:04:29] Energy consumed for all CPUs : 0.008330 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:04:29] 0.022479 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:04:44] Energy consumed for RAM : 0.002377 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:04:44] Energy consumed for all GPUs : 0.012074 kWh. Total GPU Power : 60.657000000000004 W
# [codecarbon INFO @ 16:04:44] Energy consumed for all CPUs : 0.008507 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:04:44] 0.022959 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:04:59] Energy consumed for RAM : 0.002427 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:04:59] Energy consumed for all GPUs : 0.012326 kWh. Total GPU Power : 60.496 W
# [codecarbon INFO @ 16:04:59] Energy consumed for all CPUs : 0.008684 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:04:59] 0.023438 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:05:14] Energy consumed for RAM : 0.002476 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:05:14] Energy consumed for all GPUs : 0.012578 kWh. Total GPU Power : 60.361000000000004 W
# [codecarbon INFO @ 16:05:14] Energy consumed for all CPUs : 0.008862 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:05:14] 0.023916 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:05:29] Energy consumed for RAM : 0.002526 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:05:29] Energy consumed for all GPUs : 0.012831 kWh. Total GPU Power : 60.75800000000001 W
# [codecarbon INFO @ 16:05:29] Energy consumed for all CPUs : 0.009039 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:05:29] 0.024396 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:05:44] Energy consumed for RAM : 0.002575 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:05:45] Energy consumed for all GPUs : 0.013083 kWh. Total GPU Power : 60.416000000000004 W
# [codecarbon INFO @ 16:05:45] Energy consumed for all CPUs : 0.009216 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:05:45] 0.024874 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:06:00] Energy consumed for RAM : 0.002625 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:06:00] Energy consumed for all GPUs : 0.013334 kWh. Total GPU Power : 60.335 W
# [codecarbon INFO @ 16:06:00] Energy consumed for all CPUs : 0.009393 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:06:00] 0.025352 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:06:15] Energy consumed for RAM : 0.002674 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:06:15] Energy consumed for all GPUs : 0.013587 kWh. Total GPU Power : 60.558 W
# [codecarbon INFO @ 16:06:15] Energy consumed for all CPUs : 0.009571 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:06:15] 0.025831 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:06:30] Energy consumed for RAM : 0.002724 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:06:30] Energy consumed for all GPUs : 0.013840 kWh. Total GPU Power : 60.679 W
# [codecarbon INFO @ 16:06:30] Energy consumed for all CPUs : 0.009748 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:06:30] 0.026311 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:06:45] Energy consumed for RAM : 0.002773 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:06:45] Energy consumed for all GPUs : 0.014091 kWh. Total GPU Power : 60.23700000000001 W
# [codecarbon INFO @ 16:06:45] Energy consumed for all CPUs : 0.009925 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:06:45] 0.026789 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:07:00] Energy consumed for RAM : 0.002823 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:07:00] Energy consumed for all GPUs : 0.014340 kWh. Total GPU Power : 59.78600000000001 W
# [codecarbon INFO @ 16:07:00] Energy consumed for all CPUs : 0.010102 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:07:00] 0.027265 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:07:15] Energy consumed for RAM : 0.002872 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:07:15] Energy consumed for all GPUs : 0.014589 kWh. Total GPU Power : 59.924 W
# [codecarbon INFO @ 16:07:15] Energy consumed for all CPUs : 0.010279 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:07:15] 0.027741 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:07:30] Energy consumed for RAM : 0.002922 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:07:30] Energy consumed for all GPUs : 0.014842 kWh. Total GPU Power : 60.64600000000001 W
# [codecarbon INFO @ 16:07:30] Energy consumed for all CPUs : 0.010457 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:07:30] 0.028220 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:07:45] Energy consumed for RAM : 0.002971 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:07:45] Energy consumed for all GPUs : 0.015094 kWh. Total GPU Power : 60.51 W
# [codecarbon INFO @ 16:07:45] Energy consumed for all CPUs : 0.010634 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:07:45] 0.028699 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:08:00] Energy consumed for RAM : 0.003021 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:08:00] Energy consumed for all GPUs : 0.015346 kWh. Total GPU Power : 60.400000000000006 W
# [codecarbon INFO @ 16:08:00] Energy consumed for all CPUs : 0.010811 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:08:00] 0.029177 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:08:15] Energy consumed for RAM : 0.003070 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:08:15] Energy consumed for all GPUs : 0.015596 kWh. Total GPU Power : 60.18200000000001 W
# [codecarbon INFO @ 16:08:15] Energy consumed for all CPUs : 0.010988 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:08:15] 0.029654 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:08:30] Energy consumed for RAM : 0.003120 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:08:30] Energy consumed for all GPUs : 0.015850 kWh. Total GPU Power : 61.038000000000004 W
# [codecarbon INFO @ 16:08:30] Energy consumed for all CPUs : 0.011165 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:08:30] 0.030135 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:08:45] Energy consumed for RAM : 0.003169 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:08:45] Energy consumed for all GPUs : 0.016105 kWh. Total GPU Power : 61.03 W
# [codecarbon INFO @ 16:08:45] Energy consumed for all CPUs : 0.011342 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:08:45] 0.030617 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:09:00] Energy consumed for RAM : 0.003219 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:09:00] Energy consumed for all GPUs : 0.016360 kWh. Total GPU Power : 61.24 W
# [codecarbon INFO @ 16:09:00] Energy consumed for all CPUs : 0.011519 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:09:00] 0.031098 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:09:15] Energy consumed for RAM : 0.003268 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:09:15] Energy consumed for all GPUs : 0.016612 kWh. Total GPU Power : 60.547000000000004 W
# [codecarbon INFO @ 16:09:15] Energy consumed for all CPUs : 0.011697 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:09:15] 0.031577 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:09:30] Energy consumed for RAM : 0.003318 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:09:30] Energy consumed for all GPUs : 0.016864 kWh. Total GPU Power : 60.443 W
# [codecarbon INFO @ 16:09:30] Energy consumed for all CPUs : 0.011874 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:09:30] 0.032056 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:09:45] Energy consumed for RAM : 0.003367 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:09:45] Energy consumed for all GPUs : 0.017119 kWh. Total GPU Power : 61.187000000000005 W
# [codecarbon INFO @ 16:09:45] Energy consumed for all CPUs : 0.012051 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:09:45] 0.032538 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:10:00] Energy consumed for RAM : 0.003417 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:10:00] Energy consumed for all GPUs : 0.017374 kWh. Total GPU Power : 61.13300000000001 W
# [codecarbon INFO @ 16:10:00] Energy consumed for all CPUs : 0.012228 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:10:00] 0.033019 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:10:15] Energy consumed for RAM : 0.003466 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:10:15] Energy consumed for all GPUs : 0.017624 kWh. Total GPU Power : 60.109 W
# [codecarbon INFO @ 16:10:15] Energy consumed for all CPUs : 0.012405 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:10:15] 0.033496 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:10:30] Energy consumed for RAM : 0.003516 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:10:30] Energy consumed for all GPUs : 0.017877 kWh. Total GPU Power : 60.759 W
# [codecarbon INFO @ 16:10:30] Energy consumed for all CPUs : 0.012583 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:10:30] 0.033976 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:10:45] Energy consumed for RAM : 0.003565 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:10:45] Energy consumed for all GPUs : 0.018132 kWh. Total GPU Power : 61.101 W
# [codecarbon INFO @ 16:10:45] Energy consumed for all CPUs : 0.012760 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:10:45] 0.034457 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:11:00] Energy consumed for RAM : 0.003615 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:11:00] Energy consumed for all GPUs : 0.018383 kWh. Total GPU Power : 60.179 W
# [codecarbon INFO @ 16:11:00] Energy consumed for all CPUs : 0.012937 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:11:00] 0.034934 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:11:15] Energy consumed for RAM : 0.003664 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:11:15] Energy consumed for all GPUs : 0.018634 kWh. Total GPU Power : 60.303000000000004 W
# [codecarbon INFO @ 16:11:15] Energy consumed for all CPUs : 0.013114 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:11:15] 0.035412 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:11:30] Energy consumed for RAM : 0.003714 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:11:30] Energy consumed for all GPUs : 0.018887 kWh. Total GPU Power : 60.832 W
# [codecarbon INFO @ 16:11:30] Energy consumed for all CPUs : 0.013291 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:11:30] 0.035892 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:11:45] Energy consumed for RAM : 0.003763 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:11:45] Energy consumed for all GPUs : 0.019139 kWh. Total GPU Power : 60.425000000000004 W
# [codecarbon INFO @ 16:11:45] Energy consumed for all CPUs : 0.013469 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:11:45] 0.036371 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:12:00] Energy consumed for RAM : 0.003813 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:12:00] Energy consumed for all GPUs : 0.019390 kWh. Total GPU Power : 60.191 W
# [codecarbon INFO @ 16:12:00] Energy consumed for all CPUs : 0.013646 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:12:00] 0.036849 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:12:15] Energy consumed for RAM : 0.003863 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:12:15] Energy consumed for all GPUs : 0.019646 kWh. Total GPU Power : 61.40400000000001 W
# [codecarbon INFO @ 16:12:15] Energy consumed for all CPUs : 0.013823 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:12:15] 0.037332 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:12:30] Energy consumed for RAM : 0.003912 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:12:30] Energy consumed for all GPUs : 0.019898 kWh. Total GPU Power : 60.429 W
# [codecarbon INFO @ 16:12:30] Energy consumed for all CPUs : 0.014000 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:12:30] 0.037810 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:12:45] Energy consumed for RAM : 0.003961 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:12:45] Energy consumed for all GPUs : 0.020150 kWh. Total GPU Power : 60.541000000000004 W
# [codecarbon INFO @ 16:12:45] Energy consumed for all CPUs : 0.014177 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:12:45] 0.038288 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:13:00] Energy consumed for RAM : 0.004011 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:13:00] Energy consumed for all GPUs : 0.020401 kWh. Total GPU Power : 60.445 W
# [codecarbon INFO @ 16:13:00] Energy consumed for all CPUs : 0.014354 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:13:00] 0.038767 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:13:15] Energy consumed for RAM : 0.004061 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:13:15] Energy consumed for all GPUs : 0.020657 kWh. Total GPU Power : 61.278 W
# [codecarbon INFO @ 16:13:15] Energy consumed for all CPUs : 0.014532 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:13:15] 0.039249 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:13:30] Energy consumed for RAM : 0.004110 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:13:30] Energy consumed for all GPUs : 0.020913 kWh. Total GPU Power : 61.412 W
# [codecarbon INFO @ 16:13:30] Energy consumed for all CPUs : 0.014709 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:13:30] 0.039731 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:13:45] Energy consumed for RAM : 0.004159 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:13:45] Energy consumed for all GPUs : 0.021165 kWh. Total GPU Power : 60.547000000000004 W
# [codecarbon INFO @ 16:13:45] Energy consumed for all CPUs : 0.014886 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:13:45] 0.040210 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:14:00] Energy consumed for RAM : 0.004209 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:14:00] Energy consumed for all GPUs : 0.021418 kWh. Total GPU Power : 60.778 W
# [codecarbon INFO @ 16:14:00] Energy consumed for all CPUs : 0.015063 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:14:00] 0.040690 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:14:15] Energy consumed for RAM : 0.004259 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:14:15] Energy consumed for all GPUs : 0.021670 kWh. Total GPU Power : 60.524 W
# [codecarbon INFO @ 16:14:15] Energy consumed for all CPUs : 0.015240 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:14:15] 0.041169 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:14:30] Energy consumed for RAM : 0.004308 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:14:30] Energy consumed for all GPUs : 0.021922 kWh. Total GPU Power : 60.367000000000004 W
# [codecarbon INFO @ 16:14:30] Energy consumed for all CPUs : 0.015418 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:14:30] 0.041647 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:14:45] Energy consumed for RAM : 0.004358 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:14:45] Energy consumed for all GPUs : 0.022171 kWh. Total GPU Power : 59.81 W
# [codecarbon INFO @ 16:14:45] Energy consumed for all CPUs : 0.015595 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:14:45] 0.042123 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:15:00] Energy consumed for RAM : 0.004407 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:15:00] Energy consumed for all GPUs : 0.022421 kWh. Total GPU Power : 60.125 W
# [codecarbon INFO @ 16:15:00] Energy consumed for all CPUs : 0.015772 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:15:00] 0.042600 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:15:15] Energy consumed for RAM : 0.004457 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:15:15] Energy consumed for all GPUs : 0.022674 kWh. Total GPU Power : 60.547000000000004 W
# [codecarbon INFO @ 16:15:15] Energy consumed for all CPUs : 0.015949 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:15:15] 0.043079 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:15:30] Energy consumed for RAM : 0.004506 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:15:30] Energy consumed for all GPUs : 0.022926 kWh. Total GPU Power : 60.497 W
# [codecarbon INFO @ 16:15:30] Energy consumed for all CPUs : 0.016126 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:15:30] 0.043558 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:15:45] Energy consumed for RAM : 0.004556 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:15:45] Energy consumed for all GPUs : 0.023181 kWh. Total GPU Power : 61.18400000000001 W
# [codecarbon INFO @ 16:15:45] Energy consumed for all CPUs : 0.016304 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:15:45] 0.044040 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:16:00] Energy consumed for RAM : 0.004605 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:16:00] Energy consumed for all GPUs : 0.023433 kWh. Total GPU Power : 60.626000000000005 W
# [codecarbon INFO @ 16:16:00] Energy consumed for all CPUs : 0.016481 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:16:00] 0.044519 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:16:15] Energy consumed for RAM : 0.004655 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:16:15] Energy consumed for all GPUs : 0.023686 kWh. Total GPU Power : 60.61200000000001 W
# [codecarbon INFO @ 16:16:15] Energy consumed for all CPUs : 0.016658 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:16:15] 0.044998 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:16:30] Energy consumed for RAM : 0.004704 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:16:30] Energy consumed for all GPUs : 0.023939 kWh. Total GPU Power : 60.805 W
# [codecarbon INFO @ 16:16:30] Energy consumed for all CPUs : 0.016835 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:16:30] 0.045478 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:16:45] Energy consumed for RAM : 0.004754 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:16:45] Energy consumed for all GPUs : 0.024191 kWh. Total GPU Power : 60.635 W
# [codecarbon INFO @ 16:16:45] Energy consumed for all CPUs : 0.017012 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:16:45] 0.045957 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:17:00] Energy consumed for RAM : 0.004803 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:17:00] Energy consumed for all GPUs : 0.024447 kWh. Total GPU Power : 61.43600000000001 W
# [codecarbon INFO @ 16:17:00] Energy consumed for all CPUs : 0.017189 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:17:00] 0.046440 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:17:15] Energy consumed for RAM : 0.004853 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:17:15] Energy consumed for all GPUs : 0.024700 kWh. Total GPU Power : 60.61000000000001 W
# [codecarbon INFO @ 16:17:15] Energy consumed for all CPUs : 0.017367 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:17:15] 0.046919 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:17:30] Energy consumed for RAM : 0.004902 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:17:30] Energy consumed for all GPUs : 0.024953 kWh. Total GPU Power : 60.674 W
# [codecarbon INFO @ 16:17:30] Energy consumed for all CPUs : 0.017544 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:17:30] 0.047399 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:17:45] Energy consumed for RAM : 0.004952 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:17:45] Energy consumed for all GPUs : 0.025203 kWh. Total GPU Power : 60.039 W
# [codecarbon INFO @ 16:17:45] Energy consumed for all CPUs : 0.017721 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:17:45] 0.047875 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:18:00] Energy consumed for RAM : 0.005001 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:18:00] Energy consumed for all GPUs : 0.025460 kWh. Total GPU Power : 61.685 W
# [codecarbon INFO @ 16:18:00] Energy consumed for all CPUs : 0.017898 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:18:00] 0.048359 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:18:15] Energy consumed for RAM : 0.005051 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:18:15] Energy consumed for all GPUs : 0.025713 kWh. Total GPU Power : 60.818 W
# [codecarbon INFO @ 16:18:15] Energy consumed for all CPUs : 0.018075 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:18:15] 0.048839 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:18:30] Energy consumed for RAM : 0.005100 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:18:30] Energy consumed for all GPUs : 0.025969 kWh. Total GPU Power : 61.388 W
# [codecarbon INFO @ 16:18:30] Energy consumed for all CPUs : 0.018252 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:18:30] 0.049321 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:18:45] Energy consumed for RAM : 0.005150 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:18:45] Energy consumed for all GPUs : 0.026222 kWh. Total GPU Power : 60.80900000000001 W
# [codecarbon INFO @ 16:18:45] Energy consumed for all CPUs : 0.018430 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:18:45] 0.049801 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:19:00] Energy consumed for RAM : 0.005199 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:19:00] Energy consumed for all GPUs : 0.026477 kWh. Total GPU Power : 61.226 W
# [codecarbon INFO @ 16:19:00] Energy consumed for all CPUs : 0.018607 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:19:00] 0.050283 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:19:15] Energy consumed for RAM : 0.005249 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:19:15] Energy consumed for all GPUs : 0.026728 kWh. Total GPU Power : 60.332 W
# [codecarbon INFO @ 16:19:15] Energy consumed for all CPUs : 0.018784 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:19:15] 0.050761 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:19:30] Energy consumed for RAM : 0.005298 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:19:30] Energy consumed for all GPUs : 0.026983 kWh. Total GPU Power : 60.992000000000004 W
# [codecarbon INFO @ 16:19:30] Energy consumed for all CPUs : 0.018961 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:19:30] 0.051242 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:19:45] Energy consumed for RAM : 0.005348 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:19:45] Energy consumed for all GPUs : 0.027232 kWh. Total GPU Power : 59.941 W
# [codecarbon INFO @ 16:19:45] Energy consumed for all CPUs : 0.019138 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:19:45] 0.051718 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:20:00] Energy consumed for RAM : 0.005397 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:20:00] Energy consumed for all GPUs : 0.027489 kWh. Total GPU Power : 61.625 W
# [codecarbon INFO @ 16:20:00] Energy consumed for all CPUs : 0.019315 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:20:00] 0.052201 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:20:15] Energy consumed for RAM : 0.005447 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:20:15] Energy consumed for all GPUs : 0.027743 kWh. Total GPU Power : 60.946 W
# [codecarbon INFO @ 16:20:15] Energy consumed for all CPUs : 0.019492 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:20:15] 0.052682 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:20:30] Energy consumed for RAM : 0.005496 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:20:30] Energy consumed for all GPUs : 0.027999 kWh. Total GPU Power : 61.519 W
# [codecarbon INFO @ 16:20:30] Energy consumed for all CPUs : 0.019670 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:20:30] 0.053165 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:20:45] Energy consumed for RAM : 0.005546 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:20:45] Energy consumed for all GPUs : 0.028253 kWh. Total GPU Power : 60.983000000000004 W
# [codecarbon INFO @ 16:20:45] Energy consumed for all CPUs : 0.019847 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:20:45] 0.053646 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:21:00] Energy consumed for RAM : 0.005595 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:21:00] Energy consumed for all GPUs : 0.028508 kWh. Total GPU Power : 61.17 W
# [codecarbon INFO @ 16:21:00] Energy consumed for all CPUs : 0.020024 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:21:00] 0.054128 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:21:15] Energy consumed for RAM : 0.005645 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:21:15] Energy consumed for all GPUs : 0.028764 kWh. Total GPU Power : 61.31 W
# [codecarbon INFO @ 16:21:15] Energy consumed for all CPUs : 0.020201 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:21:15] 0.054610 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:21:30] Energy consumed for RAM : 0.005694 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:21:30] Energy consumed for all GPUs : 0.029017 kWh. Total GPU Power : 60.805 W
# [codecarbon INFO @ 16:21:30] Energy consumed for all CPUs : 0.020379 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:21:30] 0.055090 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:21:45] Energy consumed for RAM : 0.005744 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:21:45] Energy consumed for all GPUs : 0.029276 kWh. Total GPU Power : 62.191 W
# [codecarbon INFO @ 16:21:45] Energy consumed for all CPUs : 0.020556 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:21:45] 0.055576 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:22:00] Energy consumed for RAM : 0.005793 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:22:00] Energy consumed for all GPUs : 0.029529 kWh. Total GPU Power : 60.751000000000005 W
# [codecarbon INFO @ 16:22:00] Energy consumed for all CPUs : 0.020733 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:22:00] 0.056056 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:22:15] Energy consumed for RAM : 0.005843 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:22:15] Energy consumed for all GPUs : 0.029784 kWh. Total GPU Power : 61.113 W
# [codecarbon INFO @ 16:22:15] Energy consumed for all CPUs : 0.020910 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:22:15] 0.056537 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:22:30] Energy consumed for RAM : 0.005893 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:22:30] Energy consumed for all GPUs : 0.030040 kWh. Total GPU Power : 61.293 W
# [codecarbon INFO @ 16:22:30] Energy consumed for all CPUs : 0.021088 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:22:30] 0.057020 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:22:45] Energy consumed for RAM : 0.005942 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:22:45] Energy consumed for all GPUs : 0.030294 kWh. Total GPU Power : 61.083 W
# [codecarbon INFO @ 16:22:45] Energy consumed for all CPUs : 0.021265 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:22:45] 0.057501 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:23:00] Energy consumed for RAM : 0.005992 kWh. RAM Power : 11.886009693145752 W
# ...
# [codecarbon INFO @ 16:51:31] 0.112569 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:51:46] Energy consumed for RAM : 0.011685 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:51:46] Energy consumed for all GPUs : 0.059544 kWh. Total GPU Power : 60.254000000000005 W
# [codecarbon INFO @ 16:51:46] Energy consumed for all CPUs : 0.041818 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:51:46] 0.113047 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:52:01] Energy consumed for RAM : 0.011735 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:52:01] Energy consumed for all GPUs : 0.059797 kWh. Total GPU Power : 60.872 W
# [codecarbon INFO @ 16:52:01] Energy consumed for all CPUs : 0.041995 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:52:01] 0.113528 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:52:16] Energy consumed for RAM : 0.011785 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:52:16] Energy consumed for all GPUs : 0.060049 kWh. Total GPU Power : 60.426 W
# [codecarbon INFO @ 16:52:16] Energy consumed for all CPUs : 0.042172 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:52:16] 0.114006 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:52:31] Energy consumed for RAM : 0.011834 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:52:31] Energy consumed for all GPUs : 0.060301 kWh. Total GPU Power : 60.495000000000005 W
# [codecarbon INFO @ 16:52:31] Energy consumed for all CPUs : 0.042350 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:52:31] 0.114485 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:52:46] Energy consumed for RAM : 0.011884 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:52:46] Energy consumed for all GPUs : 0.060553 kWh. Total GPU Power : 60.536 W
# [codecarbon INFO @ 16:52:46] Energy consumed for all CPUs : 0.042527 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:52:46] 0.114964 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:53:01] Energy consumed for RAM : 0.011933 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:53:01] Energy consumed for all GPUs : 0.060806 kWh. Total GPU Power : 60.733000000000004 W
# [codecarbon INFO @ 16:53:01] Energy consumed for all CPUs : 0.042704 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:53:01] 0.115443 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:53:16] Energy consumed for RAM : 0.011983 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:53:16] Energy consumed for all GPUs : 0.061060 kWh. Total GPU Power : 60.806000000000004 W
# [codecarbon INFO @ 16:53:16] Energy consumed for all CPUs : 0.042881 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:53:16] 0.115923 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:53:31] Energy consumed for RAM : 0.012032 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:53:31] Energy consumed for all GPUs : 0.061314 kWh. Total GPU Power : 61.095000000000006 W
# [codecarbon INFO @ 16:53:31] Energy consumed for all CPUs : 0.043058 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:53:31] 0.116405 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:53:46] Energy consumed for RAM : 0.012082 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:53:46] Energy consumed for all GPUs : 0.061567 kWh. Total GPU Power : 60.787 W
# [codecarbon INFO @ 16:53:46] Energy consumed for all CPUs : 0.043235 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:53:46] 0.116884 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:54:01] Energy consumed for RAM : 0.012131 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:54:01] Energy consumed for all GPUs : 0.061816 kWh. Total GPU Power : 59.756 W
# [codecarbon INFO @ 16:54:01] Energy consumed for all CPUs : 0.043413 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:54:01] 0.117360 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:54:16] Energy consumed for RAM : 0.012181 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:54:16] Energy consumed for all GPUs : 0.062068 kWh. Total GPU Power : 60.358000000000004 W
# [codecarbon INFO @ 16:54:16] Energy consumed for all CPUs : 0.043590 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:54:16] 0.117839 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:54:31] Energy consumed for RAM : 0.012230 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:54:31] Energy consumed for all GPUs : 0.062319 kWh. Total GPU Power : 60.345000000000006 W
# [codecarbon INFO @ 16:54:31] Energy consumed for all CPUs : 0.043767 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:54:31] 0.118317 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:54:46] Energy consumed for RAM : 0.012280 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:54:46] Energy consumed for all GPUs : 0.062570 kWh. Total GPU Power : 60.047000000000004 W
# [codecarbon INFO @ 16:54:46] Energy consumed for all CPUs : 0.043944 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:54:46] 0.118794 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:55:01] Energy consumed for RAM : 0.012329 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:55:01] Energy consumed for all GPUs : 0.062819 kWh. Total GPU Power : 59.730000000000004 W
# [codecarbon INFO @ 16:55:01] Energy consumed for all CPUs : 0.044122 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:55:01] 0.119270 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:55:16] Energy consumed for RAM : 0.012379 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:55:16] Energy consumed for all GPUs : 0.063072 kWh. Total GPU Power : 60.82 W
# [codecarbon INFO @ 16:55:16] Energy consumed for all CPUs : 0.044299 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:55:16] 0.119750 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:55:31] Energy consumed for RAM : 0.012428 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:55:31] Energy consumed for all GPUs : 0.063323 kWh. Total GPU Power : 60.162 W
# [codecarbon INFO @ 16:55:31] Energy consumed for all CPUs : 0.044476 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:55:31] 0.120227 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:55:46] Energy consumed for RAM : 0.012478 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:55:46] Energy consumed for all GPUs : 0.063575 kWh. Total GPU Power : 60.519 W
# [codecarbon INFO @ 16:55:46] Energy consumed for all CPUs : 0.044653 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:55:46] 0.120706 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:56:01] Energy consumed for RAM : 0.012527 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:56:01] Energy consumed for all GPUs : 0.063828 kWh. Total GPU Power : 60.779 W
# [codecarbon INFO @ 16:56:01] Energy consumed for all CPUs : 0.044830 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:56:01] 0.121186 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:56:16] Energy consumed for RAM : 0.012577 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:56:16] Energy consumed for all GPUs : 0.064078 kWh. Total GPU Power : 59.997 W
# [codecarbon INFO @ 16:56:16] Energy consumed for all CPUs : 0.045007 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:56:16] 0.121662 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:56:31] Energy consumed for RAM : 0.012626 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:56:31] Energy consumed for all GPUs : 0.064332 kWh. Total GPU Power : 60.952 W
# [codecarbon INFO @ 16:56:31] Energy consumed for all CPUs : 0.045185 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:56:31] 0.122143 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:56:46] Energy consumed for RAM : 0.012676 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:56:46] Energy consumed for all GPUs : 0.064584 kWh. Total GPU Power : 60.504000000000005 W
# [codecarbon INFO @ 16:56:46] Energy consumed for all CPUs : 0.045362 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:56:46] 0.122622 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:57:01] Energy consumed for RAM : 0.012725 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:57:01] Energy consumed for all GPUs : 0.064836 kWh. Total GPU Power : 60.419000000000004 W
# [codecarbon INFO @ 16:57:01] Energy consumed for all CPUs : 0.045539 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:57:01] 0.123100 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:57:16] Energy consumed for RAM : 0.012775 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:57:17] Energy consumed for all GPUs : 0.065086 kWh. Total GPU Power : 60.007 W
# [codecarbon INFO @ 16:57:17] Energy consumed for all CPUs : 0.045716 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:57:17] 0.123577 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:57:32] Energy consumed for RAM : 0.012824 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:57:32] Energy consumed for all GPUs : 0.065339 kWh. Total GPU Power : 60.846000000000004 W
# [codecarbon INFO @ 16:57:32] Energy consumed for all CPUs : 0.045893 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:57:32] 0.124057 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:57:47] Energy consumed for RAM : 0.012874 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:57:47] Energy consumed for all GPUs : 0.065590 kWh. Total GPU Power : 60.279 W
# [codecarbon INFO @ 16:57:47] Energy consumed for all CPUs : 0.046071 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:57:47] 0.124535 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:58:02] Energy consumed for RAM : 0.012923 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:58:02] Energy consumed for all GPUs : 0.065843 kWh. Total GPU Power : 60.706 W
# [codecarbon INFO @ 16:58:02] Energy consumed for all CPUs : 0.046248 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:58:02] 0.125015 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:58:17] Energy consumed for RAM : 0.012973 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:58:17] Energy consumed for all GPUs : 0.066096 kWh. Total GPU Power : 60.516 W
# [codecarbon INFO @ 16:58:17] Energy consumed for all CPUs : 0.046425 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:58:17] 0.125494 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:58:32] Energy consumed for RAM : 0.013022 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:58:32] Energy consumed for all GPUs : 0.066348 kWh. Total GPU Power : 60.539 W
# [codecarbon INFO @ 16:58:32] Energy consumed for all CPUs : 0.046602 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:58:32] 0.125973 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:58:47] Energy consumed for RAM : 0.013072 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:58:47] Energy consumed for all GPUs : 0.066600 kWh. Total GPU Power : 60.63100000000001 W
# [codecarbon INFO @ 16:58:47] Energy consumed for all CPUs : 0.046779 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:58:47] 0.126452 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:59:02] Energy consumed for RAM : 0.013121 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:59:02] Energy consumed for all GPUs : 0.066855 kWh. Total GPU Power : 61.084 W
# [codecarbon INFO @ 16:59:02] Energy consumed for all CPUs : 0.046957 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:59:02] 0.126933 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:59:17] Energy consumed for RAM : 0.013171 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:59:17] Energy consumed for all GPUs : 0.067108 kWh. Total GPU Power : 60.707 W
# [codecarbon INFO @ 16:59:17] Energy consumed for all CPUs : 0.047134 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:59:17] 0.127413 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:59:32] Energy consumed for RAM : 0.013220 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:59:32] Energy consumed for all GPUs : 0.067362 kWh. Total GPU Power : 60.876000000000005 W
# [codecarbon INFO @ 16:59:32] Energy consumed for all CPUs : 0.047311 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:59:32] 0.127893 kWh of electricity used since the beginning.
# [codecarbon INFO @ 16:59:47] Energy consumed for RAM : 0.013270 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 16:59:47] Energy consumed for all GPUs : 0.067613 kWh. Total GPU Power : 60.308 W
# [codecarbon INFO @ 16:59:47] Energy consumed for all CPUs : 0.047488 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 16:59:47] 0.128371 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:00:02] Energy consumed for RAM : 0.013319 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 17:00:02] Energy consumed for all GPUs : 0.067863 kWh. Total GPU Power : 60.083 W
# [codecarbon INFO @ 17:00:02] Energy consumed for all CPUs : 0.047665 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:00:02] 0.128848 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:00:17] Energy consumed for RAM : 0.013369 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 17:00:17] Energy consumed for all GPUs : 0.068114 kWh. Total GPU Power : 60.193 W
# [codecarbon INFO @ 17:00:17] Energy consumed for all CPUs : 0.047842 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:00:17] 0.129325 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:00:32] Energy consumed for RAM : 0.013419 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 17:00:32] Energy consumed for all GPUs : 0.068367 kWh. Total GPU Power : 60.697 W
# [codecarbon INFO @ 17:00:32] Energy consumed for all CPUs : 0.048020 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:00:32] 0.129805 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:00:47] Energy consumed for RAM : 0.013468 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 17:00:47] Energy consumed for all GPUs : 0.068619 kWh. Total GPU Power : 60.531 W
# [codecarbon INFO @ 17:00:47] Energy consumed for all CPUs : 0.048197 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:00:47] 0.130284 kWh of electricity used since the beginning.
# [codecarbon INFO @ 17:01:02] Energy consumed for RAM : 0.013518 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 17:01:02] Energy consumed for all GPUs : 0.068873 kWh. Total GPU Power : 60.945 W
# [codecarbon INFO @ 17:01:02] Energy consumed for all CPUs : 0.048374 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:01:02] 0.130765 kWh of electricity used since the beginning.
# C:\Users\USTB\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# [codecarbon INFO @ 17:01:10] Energy consumed for RAM : 0.013544 kWh. RAM Power : 11.886009693145752 W
# [codecarbon INFO @ 17:01:10] Energy consumed for all GPUs : 0.069008 kWh. Total GPU Power : 59.98500000000001 W
# [codecarbon INFO @ 17:01:10] Energy consumed for all CPUs : 0.048470 kWh. Total CPU Power : 42.5 W
# [codecarbon INFO @ 17:01:10] 0.131022 kWh of electricity used since the beginning.
# {'eval_loss': nan, 'eval_accuracy': 0.5191982612895436, 'eval_f1': 0.3548803884191762, 'eval_precision': 0.2695668345260852, 'eval_recall': 0.5191982612895436, 'eval_runtime': 4105.9426, 'eval_samples_per_second': 2.017, 'eval_steps_per_second': 0.504, 'epoch': 1.0}
# Inference Time: 4105.9466 seconds
# CPU Usage: 3.50%
# RAM Usage: -9728.59 MB
# Energy Consumption: 0.001514 kWh
